# %%
import numpy as np
import json
import pandas as pd

data = pd.read_json("./data/headline_cities_and_countries.json")
data = data.replace({None: np.nan})

data.head(10)
# Out:
#                                   headline countries         cities
# 0                 Zika Outbreak Hits Miami       NaN          Miami
# 1          Could Zika Reach New York City?       NaN  New York City
# 2        First Case of Zika in Miami Beach       NaN    Miami Beach
# 3  Mystery Virus Spreads in Recife, Brazil    Brazil         Recife
# 4  Dallas man comes down with case of Zika       NaN         Dallas
# 5        Trinidad confirms first Zika case       NaN       Trinidad
# 6   Zika Concerns are Spreading in Houston       NaN        Houston
# 7    Geneve Scientists Battle to Find Cure       NaN         Geneve
# 8    The CDC in Atlanta is Growing Worried       NaN        Atlanta
# 9       Zika Infested Monkeys in Sao Paulo       NaN      Sao Paulo

# %% [markdown]
# Logic for finding the latitude, longitude for the city
#
# if cities[n] == Nan and countries[n] == Nan
#         latitude[n] = Nan, longitude[n] = Nan
#     elif cities[n] == NaN and country[n] != Nan:
#         get the latitude and longitude using countries[n]
#     elif count(cities[n] == 1):
#         get the latitude and longitude using cities[n]
#     elif:
#         arbitration(city[n]

# %%
data.loc[6:10, ["headline","countries"]]
# Out:
#                                   headline countries
# 6   Zika Concerns are Spreading in Houston       NaN
# 7    Geneve Scientists Battle to Find Cure       NaN
# 8    The CDC in Atlanta is Growing Worried       NaN
# 9       Zika Infested Monkeys in Sao Paulo       NaN
# 10   Brownsville teen contracts Zika virus       NaN

# %%
data.describe()
# Out:
#                               headline countries  cities
# count                              650        15     608
# unique                             647        10     573
# top     Spanish Flu Outbreak in Lisbon    Brazil  Monroe
# freq                                 2         3       4

# %%
data[data.countries.notnull()].describe()
# Out:
#                                   headline countries       cities
# count                                   15        15           15
# unique                                  15        10           14
# top     Belize City under threat from Zika  Malaysia  Panama City
# freq                                     1         3            2

# %%
data[data.cities.notnull()].describe()
# Out:
#                                     headline countries  cities
# count                                    608        15     608
# unique                                   605        10     573
# top     Spanish Flu Spreading through Madrid  Malaysia  Monroe
# freq                                       2         3       4

# %%
data.loc[data["cities"] == "Monroe", "headline"].value_counts()
# Out:
# Spike of Syphilis Cases in West Monroe                                         1
# The Spread of Respiratory Syncytial Virus in Monroe has been Confirmed         1
# Lower Hospitalization in Monroe after Hepatitis D Vaccine becomes Mandatory    1
# West Nile Virus Hits Monroe                                                    1
# Name: headline, dtype: int64

# %%
cities = (data.cities.value_counts()>1)
for city in cities[cities == True].index:
# Out:
# Index(['Monroe', 'Madrid', 'Miami', 'Barcelona', 'Norwalk', 'Jefferson',
#        'Cancun', 'Panama City', 'Fairfield', 'Ibadan', 'Hollywood',
#        'Greenville', 'Bedford', 'Birmingham', 'Richmond', 'Colombo',
#        'Palm Springs', 'Zanzibar', 'Edinburgh', 'Johannesburg', 'Rochester',
#        'Cambridge', 'Albany', 'Melbourne', 'San Jose', 'London', 'Orange',
#        'Lisbon'],
#       dtype='object')

# %%
import geonamescache
gc = geonamescache.GeonamesCache()
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
def find_latlon_for_max_population(city_name):
    if not city_name:
        return dict(cities=np.nan, latitude=np.nan, longitude=np.nan)
    else:
        city = max(gc.get_cities_by_name(city_name),key=lambda x: list(x.values())[0]['population'])
        city = list(city.values())[0]
        return dict(cities=city['name'], latitude=city['latitude'], longitude=city['longitude'])

city_rep = pd.Series(data.cities.values)
city_rep.fillna(value=0,inplace=True)
for city_name in city_rep:
    find_latlon_for_max_population(city_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-285-edc2caaa4d07> in <module>
#      10 city_rep.fillna(value=0,inplace=True)
#      11 for city_name in city_rep:
# ---> 12     find_latlon_for_max_population(city_name)
#
# <ipython-input-285-edc2caaa4d07> in find_latlon_for_max_population(city_name)
#       3         return dict(cities=np.nan, latitude=np.nan, longitude=np.nan)
#       4     else:
# ----> 5         city = max(gc.get_cities_by_name(city_name),key=lambda x: list(x.values())[0]['population'])
#       6         city = list(city.values())[0]
#       7         return dict(cities=city['name'], latitude=city['latitude'], longitude=city['longitude'])
#
# ValueError: max() arg is an empty sequence

# %%
city = gc.get_cities_by_name("Madrid")
# Out:
#   File "<ipython-input-154-6899768507d1>", line 1
#     {city} = gc.get_cities_by_name("Madrid")
#                                             ^
# SyntaxError: can't assign to literal

# %%
for i in city:
    for v in i.values():
        print(v["geonameid"],v["name"], v["population"])
# Out:
# 3675707 Madrid 50437
# 3117735 Madrid 3255944

# %%
v["population"]
# Out:
# array({'geonameid': 3675707, 'name': 'Madrid', 'latitude': 4.73245, 'longitude': -74.26419, 'countrycode': 'CO', 'population': 50437, 'timezone': 'America/Bogota', 'admin1code': '33'},
#       dtype=object)

# %%
df = df.assign(Latitude=latitudes, Longitude=longitudes)
df.head()

# %%
city_rep = pd.Series(data.cities.values)
city_rep.fillna(value=0,inplace=True)
for city_name in city_rep:
    print(city_name)
# Out:
# Miami
# New York City
# Miami Beach
# Recife
# Dallas
# Trinidad
# Houston
# Geneve
# Atlanta
# Sao Paulo
# Brownsville
# St. Louis
# San Juan
# Galveston
# Manila
# Iloilo
# Los Angeles
#
# Orlando
#
# Chicago
# Tampa
# Flint
# Baltimore
# London
# Ho Chi Minh City
# Philadelphia
# Boston
# Paris
# San Diego
# Bangkok
# Beijing
# Salvador
# Kuala Lumpur
# Yangon
# Tallahassee
# San Francisco
# Bethesda
# Townsville
# Mandaluyong City
# Santa Rosa
# San Salvador
# Cleveland
# Austin
# Piracicaba
# Lima
# Toronto
# Bogota
#
# Brisbane
# Dakar
# Havana
# Key West
# Vancouver
# Seattle
# Nashville
# Saint Croix
# Fort Collins
# Klang
# Guatemala City
# Madison
# Sarasota
# Entebbe
#
# Brasilia
# Jacksonville
# Shenzhen
# Caracas
# Quezon City
# Sydney
# Mumbai
# Pune
# Hanoi
#
# Silver Spring
# Delhi
#
# Belize City
# Campinas
# Soyapango
# Rome
# Seoul
# Quebec
# Mexico City
# Rochester
# El Paso
# Cucuta
# Jakarta
#
# Salt Lake City
# San Antonio
# Kampala
# Rockhampton
# Tegucigalpa
# ...
